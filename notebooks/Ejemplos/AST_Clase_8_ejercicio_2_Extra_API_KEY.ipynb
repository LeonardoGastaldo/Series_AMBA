# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales</h1>
#     <h3>Clase 8</h3>
#     <h3>EXTRA - Ejercicio 2 - API KEY</h3>
#         <p>Docente: Rodrigo Del Rosso<p>
#         <p>Asistente: Sebastián Calcagno<p>
# </div>

# %% [markdown]
# [Enlace 1 documentacion general a considerar](https://docs.nixtla.io/)
#
# [Enlace 2 documentacion particular a considerar](https://docs.nixtla.io/docs/getting-started-setting_up_your_api_key)

# %% [markdown]
# Pasos para obtener la API KEY =
#
# ## Paso 1: Crear una cuenta en TimeGPT y generar la API key
#
# * Ir a [dashboard.nixtla.io](https://dashboard.nixtla.io/sign_in)
# * Loguearse con Google, GitHub
# * Crear tu API key yendo a 'API Keys' en el menu y haciendo click en 'Create New API Key'
# * Tu nueva key aparecera. Copiarla usando el boton de la derecha.
#
# <img src="https://github.com/Nixtla/nixtla/blob/main/nbs/img/dashboard.png?raw=true" alt="Dashboard for TimeGPT API keys. Keys is in the middle, with trash and copy buttons on the right." width="700" />
#
#
# Fuente = https://docs.nixtla.io/docs/getting-started-timegpt_quickstart

# %% [markdown]
# ## Paso 2: Instalar la API KEY

# %%
# !pip install nixtla
# Out:
# Collecting nixtla
#   Downloading nixtla-0.7.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types in /usr/local/lib/python3.12/dist-packages (from nixtla) (0.7.0)
# Requirement already satisfied: httpx[zstd] in /usr/local/lib/python3.12/dist-packages (from nixtla) (0.28.1)
# Requirement already satisfied: narwhals>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from nixtla) (2.19.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from nixtla) (3.11.8)
# Requirement already satisfied: pandas<3.0.0 in /usr/local/lib/python3.12/dist-packages (from nixtla) (2.2.2)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.12/dist-packages (from nixtla) (2.12.3)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from nixtla) (9.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nixtla) (4.67.3)
# Collecting utilsforecast>=0.2.15 (from nixtla)
#   Downloading utilsforecast-0.2.15-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->nixtla) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->nixtla) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->nixtla) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0->nixtla) (2026.1)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10->nixtla) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10->nixtla) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10->nixtla) (0.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from utilsforecast>=0.2.15->nixtla) (26.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx[zstd]->nixtla) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx[zstd]->nixtla) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx[zstd]->nixtla) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx[zstd]->nixtla) (3.11)
# Requirement already satisfied: zstandard>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from httpx[zstd]->nixtla) (0.25.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx[zstd]->nixtla) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0->nixtla) (1.17.0)
# Downloading nixtla-0.7.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.1 MB/s eta 0:00:00
# Downloading utilsforecast-0.2.15-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: utilsforecast, nixtla
# Successfully installed nixtla-0.7.3 utilsforecast-0.2.15

# %%
from nixtla import NixtlaClient

# %%
nixtla_client = NixtlaClient(
    api_key = 'nixak-h8iV80neQevJ6Zea6Vvw5QtyhIK6ADThKjuvDgp8jVZJiqlnO8C9PyKydKrMxRokzGynSddzUG30T4rc'
)

# %% [markdown]
# ## Paso 3:
#
# Validar la API key

# %%
#  Este método devolverá Verdadero si la clave API es válida y Falso en caso contrario.

nixtla_client.validate_api_key()



# Para tener acceso completo a las funcionalidades de TimeGPT, además de una clave API válida, también necesita créditos suficientes en su cuenta.
# Puede consultar sus créditos y funcionalidades disponibles en la sección Uso de su panel de control.
# Out:
# True

# %% [markdown]
# https://docs.nixtla.io/docs/capabilities-anomaly-detection-quickstart
